# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import random
import math

# %%
imdb=pd.read_csv("IMDB.csv")

# %%
imdb
# Out:
#        X                              Title  Rating  TotalVotes     Genre1  \
# 0      1            12 Years a Slave (2013)     8.1      496092  Biography
# 1      2                   127 Hours (2010)     7.6      297075  Adventure
# 2      3                       50/50 (2011)     7.7      283935     Comedy
# 3      4                  About Time (2013)     7.8      225412     Comedy
# 4      5                       Amour (2012)     7.9       76121      Drama
# ..   ...                                ...     ...         ...        ...
# 112  114                    Whiplash (2014)     8.5      492285      Drama
# 113  115              Wreck-It Ralph (2012)     7.7      295125  Animation
# 114  116  X-Men: Days of Future Past (2014)     8.0      560736     Action
# 115  117          X-Men: First Class (2011)     7.8      556713     Action
# 116  118                    Zootopia (2016)     8.1      309474  Animation
#
# ...

# %%
imdb.describe()
# Out:
#                 X      Rating    TotalVotes  MetaCritic        Budget  \
# count  117.000000  117.000000  1.170000e+02  110.000000  1.140000e+02
# mean    59.940171    7.873504  3.755791e+05   77.809091  7.459649e+07
# std     34.017564    0.237586  2.627056e+05    8.857170  7.507881e+07
# min      1.000000    7.500000  2.601600e+04   62.000000  1.000000e+06
# 25%     31.000000    7.700000  2.223430e+05   72.000000  1.500000e+07
# 50%     60.000000    7.800000  3.375710e+05   77.500000  4.000000e+07
# 75%     89.000000    8.000000  5.125260e+05   82.750000  1.487500e+08
# max    118.000000    8.800000  1.609713e+06  100.000000  2.600000e+08
#
#             CVotes10       CVotes09       CVotes08       CVotes07  \
# count     117.000000     117.000000     117.000000     117.000000
# mean    65258.683761   82614.264957  113108.444444   69140.401709
# std     79129.569619   74464.561570   66478.990047   36329.756937
# min      2060.000000    4083.000000    9078.000000    5309.000000
# ...

# %%
imdb.mean()
# Out:
# X               5.994017e+01
# Rating          7.873504e+00
# TotalVotes      3.755791e+05
# MetaCritic      7.780909e+01
# Budget          7.459649e+07
# CVotes10        6.525868e+04
# CVotes09        8.261426e+04
# CVotes08        1.131084e+05
# CVotes07        6.914040e+04
# CVotes06        2.507250e+04
# CVotes05        9.135974e+03
# CVotes04        3.879692e+03
# CVotes03        2.213795e+03
# CVotes02        1.527333e+03
# CVotes01        3.644590e+03
# CVotesMale      2.431412e+05
# CVotesFemale    5.779581e+04
# CVotesU18       1.615538e+03
# CVotesU18M      1.204581e+03
# CVotesU18F      4.602564e+02
# CVotes1829      1.482222e+05
# CVotes1829M     1.147331e+05
# CVotes1829F     3.207433e+04
# CVotes3044      1.116459e+05
# CVotes3044M     9.264085e+04
# CVotes3044F     1.738523e+04
# CVotes45A       2.184255e+04
# CVotes45AM      1.774393e+04
# CVotes45AF      3.695197e+03
# CVotes1000      6.004188e+02
# CVotesUS        4.852763e+04
# CVotesnUS       1.701294e+05
# ...

# %%
imdb.median()
# Out:
# X                     60.0
# Rating                 7.8
# TotalVotes        337571.0
# MetaCritic            77.5
# Budget          40000000.0
# CVotes10           47292.0
# CVotes09           64769.0
# CVotes08          106673.0
# CVotes07           67804.0
# CVotes06           24268.0
# CVotes05            8530.0
# CVotes04            3339.0
# CVotes03            1854.0
# CVotes02            1123.0
# CVotes01            2667.0
# CVotesMale        222663.0
# CVotesFemale       51558.0
# CVotesU18           1234.0
# CVotesU18M           897.0
# CVotesU18F           305.0
# CVotes1829        129202.0
# CVotes1829M       101741.0
# CVotes1829F        29003.0
# CVotes3044        104268.0
# CVotes3044M        88233.0
# CVotes3044F        15227.0
# CVotes45A          19151.0
# CVotes45AM         16351.0
# CVotes45AF          3440.0
# CVotes1000           622.0
# CVotesUS           46033.0
# CVotesnUS         155972.0
# VotesM                 7.8
# VotesF                 7.9
# ...

# %%
imdb.skew()
# Out:
# X              -0.009063
# Rating          1.004290
# TotalVotes      1.619784
# MetaCritic      0.380997
# Budget          0.940824
# CVotes10        3.880905
# CVotes09        2.445842
# CVotes08        0.573914
# CVotes07        0.076997
# CVotes06        0.323721
# CVotes05        0.663502
# CVotes04        0.913277
# CVotes03        1.179994
# CVotes02        1.324033
# CVotes01        1.664146
# CVotesMale      1.630442
# CVotesFemale    1.242900
# CVotesU18       1.128882
# CVotesU18M      1.316692
# CVotesU18F      7.321790
# CVotes1829      1.677213
# CVotes1829M     1.747071
# CVotes1829F     1.237307
# CVotes3044      1.525409
# CVotes3044M     1.501856
# CVotes3044F     1.447886
# CVotes45A       1.144535
# CVotes45AM      1.160284
# CVotes45AF      1.020530
# CVotes1000      3.146053
# CVotesUS        1.667581
# CVotesnUS       1.514655
# VotesM          0.966669
# VotesF         -0.039476
# VotesU18       -1.514961
# VotesU18M      -0.944425
# VotesU18F      -0.462355
# ...

# %%
imdb1 = pd.read_csv('IMDB.csv' ,  usecols = ['Title','Rating','Genre1'])

# %%
imdb1
# Out:
#                                  Title  Rating     Genre1
# 0              12 Years a Slave (2013)     8.1  Biography
# 1                     127 Hours (2010)     7.6  Adventure
# 2                         50/50 (2011)     7.7     Comedy
# 3                    About Time (2013)     7.8     Comedy
# 4                         Amour (2012)     7.9      Drama
# ..                                 ...     ...        ...
# 112                    Whiplash (2014)     8.5      Drama
# 113              Wreck-It Ralph (2012)     7.7  Animation
# 114  X-Men: Days of Future Past (2014)     8.0     Action
# 115          X-Men: First Class (2011)     7.8     Action
# 116                    Zootopia (2016)     8.1  Animation
#
# [117 rows x 3 columns]

# %%
imdb
# Out:
#        X                              Title  Rating  TotalVotes     Genre1  \
# 0      1            12 Years a Slave (2013)     8.1      496092  Biography
# 1      2                   127 Hours (2010)     7.6      297075  Adventure
# 2      3                       50/50 (2011)     7.7      283935     Comedy
# 3      4                  About Time (2013)     7.8      225412     Comedy
# 4      5                       Amour (2012)     7.9       76121      Drama
# ..   ...                                ...     ...         ...        ...
# 112  114                    Whiplash (2014)     8.5      492285      Drama
# 113  115              Wreck-It Ralph (2012)     7.7      295125  Animation
# 114  116  X-Men: Days of Future Past (2014)     8.0      560736     Action
# 115  117          X-Men: First Class (2011)     7.8      556713     Action
# 116  118                    Zootopia (2016)     8.1      309474  Animation
#
# ...

# %%
imdb2 = pd.read_csv('IMDB.csv' ,  usecols = ['Title','Rating','Genre2','MetaCritic'])

# %%
imdb2
# Out:
#                                  Title  Rating     Genre2  MetaCritic
# 0              12 Years a Slave (2013)     8.1      Drama        96.0
# 1                     127 Hours (2010)     7.6  Biography        82.0
# 2                         50/50 (2011)     7.7      Drama        72.0
# 3                    About Time (2013)     7.8      Drama         NaN
# 4                         Amour (2012)     7.9    Romance        94.0
# ..                                 ...     ...        ...         ...
# 112                    Whiplash (2014)     8.5      Music        88.0
# 113              Wreck-It Ralph (2012)     7.7  Adventure        72.0
# 114  X-Men: Days of Future Past (2014)     8.0  Adventure        74.0
# 115          X-Men: First Class (2011)     7.8  Adventure        65.0
# 116                    Zootopia (2016)     8.1  Adventure        78.0
#
# [117 rows x 4 columns]

# %%
imdb2.describe()
# Out:
#            Rating  MetaCritic
# count  117.000000  110.000000
# mean     7.873504   77.809091
# std      0.237586    8.857170
# min      7.500000   62.000000
# 25%      7.700000   72.000000
# 50%      7.800000   77.500000
# 75%      8.000000   82.750000
# max      8.800000  100.000000

# %%
df=pd.read_excel('IMDB.xlsx')
df
# Out:
#        X                              Title  Rating  TotalVotes     Genre1  \
# 0      1            12 Years a Slave (2013)     8.1      496092  Biography
# 1      2                   127 Hours (2010)     7.6      297075  Adventure
# 2      3                       50/50 (2011)     7.7      283935     Comedy
# 3      4                  About Time (2013)     7.8      225412     Comedy
# 4      5                       Amour (2012)     7.9       76121      Drama
# ..   ...                                ...     ...         ...        ...
# 112  114                    Whiplash (2014)     8.5      492285      Drama
# 113  115              Wreck-It Ralph (2012)     7.7      295125  Animation
# 114  116  X-Men: Days of Future Past (2014)     8.0      560736     Action
# 115  117          X-Men: First Class (2011)     7.8      556713     Action
# 116  118                    Zootopia (2016)     8.1      309474  Animation
#
# ...

# %%
xls_file = pd.ExcelFile('IMDB.xlsx')
xls_file.sheet_names
# Out:
# ['movies', 'by genre']

# %%
df=pd.read_excel('IMDB.xlsx',sheet_name=0,index_col='X')
df
# Out:
#                                  Title  Rating  TotalVotes     Genre1  \
# X
# 1              12 Years a Slave (2013)     8.1      496092  Biography
# 2                     127 Hours (2010)     7.6      297075  Adventure
# 3                         50/50 (2011)     7.7      283935     Comedy
# 4                    About Time (2013)     7.8      225412     Comedy
# 5                         Amour (2012)     7.9       76121      Drama
# ..                                 ...     ...         ...        ...
# 114                    Whiplash (2014)     8.5      492285      Drama
# 115              Wreck-It Ralph (2012)     7.7      295125  Animation
# 116  X-Men: Days of Future Past (2014)     8.0      560736     Action
# 117          X-Men: First Class (2011)     7.8      556713     Action
# 118                    Zootopia (2016)     8.1      309474  Animation
#
#         Genre2   Genre3  MetaCritic       Budget  Runtime  CVotes10  ...  \
# ...

# %%
movies_df=pd.read_json('IMDB.json')
movies_df
# Out:
#        X                              Title  Rating  TotalVotes     Genre1  \
# 0      1            12 Years a Slave�(2013)     8.1      496092  Biography
# 1      2                   127 Hours�(2010)     7.6      297075  Adventure
# 2      3                       50/50�(2011)     7.7      283935     Comedy
# 3      4                  About Time�(2013)     7.8      225412     Comedy
# 4      5                       Amour�(2012)     7.9       76121      Drama
# ..   ...                                ...     ...         ...        ...
# 112  114                    Whiplash�(2014)     8.5      492285      Drama
# 113  115              Wreck-It Ralph�(2012)     7.7      295125  Animation
# 114  116  X-Men: Days of Future Past�(2014)     8.0      560736     Action
# 115  117          X-Men: First Class�(2011)     7.8      556713     Action
# 116  118                    Zootopia�(2016)     8.1      309474  Animation
#
# ...

# %%
movies_df.shape
# Out:
# (117, 58)

# %%
html_df=pd.read_html('IMDB.html')
html_df
# Out:
# [      0                                  1       2           3       4   \
#  0      X                              Title  Rating  TotalVotes  Genre1
#  1      1             12 Years a Slave(2013)     8.1         496     092
#  2      2                   127 Hours (2010)     7.6         297     075
#  3      3                       50/50 (2011)     7.7         283     935
#  4      4                  About Time (2013)     7.8         225     412
#  ..   ...                                ...     ...         ...     ...
#  113  114                    Whiplash (2014)     8.5         492     285
#  114  115              Wreck-It Ralph (2012)     7.7         295     125
#  115  116  X-Men: Days of Future Past (2014)       8         560     736
#  116  117          X-Men: First Class (2011)     7.8         556     713
#  117  118                    Zootopia (2016)     8.1         309     474
#
#              5          6           7       8        9   ...        48  \
# ...

# %%
pickle_df=pd.read_pickle('IMDB.p')
pickle_df
# Out:
#        X                               Title  Rating  TotalVotes     Genre1  \
# 0      1            12 Years a SlaveÂ (2013)     8.1      496092  Biography
# 1      2                   127 HoursÂ (2010)     7.6      297075  Adventure
# 2      3                       50/50Â (2011)     7.7      283935     Comedy
# 3      4                  About TimeÂ (2013)     7.8      225412     Comedy
# 4      5                       AmourÂ (2012)     7.9       76121      Drama
# ..   ...                                 ...     ...         ...        ...
# 112  114                    WhiplashÂ (2014)     8.5      492285      Drama
# 113  115              Wreck-It RalphÂ (2012)     7.7      295125  Animation
# 114  116  X-Men: Days of Future PastÂ (2014)     8.0      560736     Action
# 115  117          X-Men: First ClassÂ (2011)     7.8      556713     Action
# 116  118                    ZootopiaÂ (2016)     8.1      309474  Animation
#
# ...

# %%
import sqlite3

# %%
conn = sqlite3.connect("IMDB.sqlite")
sql_df=pd.read_sql_query("Select * from IMDB;",conn)
sql_df
# Out:
#        X                              Title  Rating  TotalVotes     Genre1  \
# 0      1            12 Years a Slave (2013)     8.1      496092  Biography
# 1      2                   127 Hours (2010)     7.6      297075  Adventure
# 2      3                       50/50 (2011)     7.7      283935     Comedy
# 3      4                  About Time (2013)     7.8      225412     Comedy
# 4      5                       Amour (2012)     7.9       76121      Drama
# ..   ...                                ...     ...         ...        ...
# 112  114                    Whiplash (2014)     8.5      492285      Drama
# 113  115              Wreck-It Ralph (2012)     7.7      295125  Animation
# 114  116  X-Men: Days of Future Past (2014)     8.0      560736     Action
# 115  117          X-Men: First Class (2011)     7.8      556713     Action
# 116  118                    Zootopia (2016)     8.1      309474  Animation
#
# ...
